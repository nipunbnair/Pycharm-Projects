# %%
import time
start= time.time()

# %%
def DNAToRNA(dnaseq):
    RNASeq = ''
    for i in dnaseq:
        if i == 'A':
            RNASeq += 'U'
        elif i == 'C':
            RNASeq += 'G'
        elif i == 'T':
            RNASeq += 'A'
        else:
            RNASeq += 'C'
    return RNASeq

# %%
# RNA codon table
def RNA2PolyPeptide(rna):
    Dict = {"UUU":"P", "UUC":"P", "UUA":"L", "UUG":"L",
        "UCU":"S", "UCC":"S", "UCA":"S", "UCG":"S",
        "UAU":"Y", "UAC":"Y", "UAA":"STOP", "UAG":"STOP",
        "UGU":"C", "UGC":"C", "UGA":"STOP", "UGG":"W",
        "CUU":"L", "CUC":"L", "CUA":"L", "CUG":"L",
        "CCU":"P", "CCC":"P", "CCA":"P", "CCG":"P",
        "CAU":"H", "CAC":"H", "CAA":"Q", "CAG":"Q",
        "CGU":"R", "CGC":"R", "CGA":"R", "CGG":"R",
        "AUU":"I", "AUC":"I", "AUA":"I", "AUG":"M",
        "ACU":"T", "ACC":"T", "ACA":"T", "ACG":"T",
        "AAU":"N", "AAC":"N", "AAA":"K", "AAG":"K",
        "AGU":"S", "AGC":"S", "AGA":"R", "AGG":"R",
        "GUU":"V", "GUC":"V", "GUA":"V", "GUG":"V",
        "GCU":"A", "GCC":"A", "GCA":"A", "GCG":"A",
        "GAU":"D", "GAC":"D", "GAA":"E", "GAG":"E",
        "GGU":"G", "GGC":"G", "GGA":"G", "GGG":"G",}
    
    codons=[]
    polypeptideList=[]
# As we need to stop the conversion when we get a stop codon     
    for i in range(0,len(rna)-2,3):
        first = rna[i]
        second = rna[i+1]
        third = rna[i+2]
        codons.append(first+second+third)
        
    for i in codons:
        if Dict[i] == "STOP":
                break
        else:
               polypeptideList.append(Dict[i])
        
    return "".join(polypeptideList)

# %%
Genome="..."
print(Genome)
# Out:
# ...

# %%
# Convert to RNA
RNA = DNAToRNA(Genome)
print(RNA)
# Out:
# ...

# %%
# Convert to PolyPeptide
Polypep = RNA2PolyPeptide(RNA)
print(Polypep)
end=time.time()
# Out:
# YRMCVCRWCSRNDL

# %%
print(f"The Run time is {end-start} seconds")
# Out:
# The Run time is 4.987796306610107 seconds
