# %%
import itertools
ParentMass = 736
Amino="CAACATCAGTTTTGAAGTCCT"
AminoWeight={'G':57,'A':71,'S':87,'P':97,'V':99,'T':101,'C':103,'I':113,'L':113,'N':114,'D':115,'K':128,'Q':128,'E':129,'M':131,'H':137,'F':147,'R':156,'Y':163,'W':186}
def getAminoWeight(x):
    w=0
    for i in x:
        w=w+AminoWeight[i]
        
    return w

# %%
def permutate_all_substrings(text):
    permutations = []
    length=5
    for p in itertools.permutations(text, length):
         permutations.append(p)
    return permutations
        
AllPossible = permutate_all_substrings(Amino)
print(len(AllPossible))
AllPossible
# Out:
# 2441880
# [('C', 'A', 'A', 'C', 'A'),
#  ('C', 'A', 'A', 'C', 'T'),
#  ('C', 'A', 'A', 'C', 'C'),
#  ('C', 'A', 'A', 'C', 'A'),
#  ('C', 'A', 'A', 'C', 'G'),
#  ('C', 'A', 'A', 'C', 'T'),
#  ('C', 'A', 'A', 'C', 'T'),
#  ('C', 'A', 'A', 'C', 'T'),
#  ('C', 'A', 'A', 'C', 'T'),
#  ('C', 'A', 'A', 'C', 'G'),
#  ('C', 'A', 'A', 'C', 'A'),
#  ('C', 'A', 'A', 'C', 'A'),
#  ('C', 'A', 'A', 'C', 'G'),
#  ('C', 'A', 'A', 'C', 'T'),
#  ('C', 'A', 'A', 'C', 'C'),
#  ('C', 'A', 'A', 'C', 'C'),
#  ('C', 'A', 'A', 'C', 'T'),
#  ('C', 'A', 'A', 'A', 'C'),
#  ('C', 'A', 'A', 'A', 'T'),
#  ('C', 'A', 'A', 'A', 'C'),
#  ('C', 'A', 'A', 'A', 'A'),
#  ('C', 'A', 'A', 'A', 'G'),
#  ('C', 'A', 'A', 'A', 'T'),
#  ('C', 'A', 'A', 'A', 'T'),
#  ('C', 'A', 'A', 'A', 'T'),
#  ('C', 'A', 'A', 'A', 'T'),
#  ('C', 'A', 'A', 'A', 'G'),
#  ('C', 'A', 'A', 'A', 'A'),
#  ('C', 'A', 'A', 'A', 'A'),
#  ('C', 'A', 'A', 'A', 'G'),
#  ('C', 'A', 'A', 'A', 'T'),
#  ('C', 'A', 'A', 'A', 'C'),
#  ('C', 'A', 'A', 'A', 'C'),
# ...

# %%
List=[]
for k in AllPossible:
    # print(getAminoWeight(k))
    if getAminoWeight(k) == ParentMass:
           List.append(k)

# %%
print(List)
# Out:
# []

# %%
PP={'AAA':'K','AAC':'N','AAG':'K','AAU':'N','ACA':'T','ACC':'T','ACG':'U','AGA':'R','AGC':'S','AGG':'R','AGU':'S','AUA':'I','AUC':'I','AUG':'M','AUU':'I',
    'CAA':'Q','CAC':'H','CAG':'Q','CAU':'H','CCA':'P','CCC':'P','CCG':'P','CCU':'P','CGA':'R','CGC':'R','CGG':'R','CGU':'R','CUA':'L','CUC':'L',
   'CUG':'L','CUU':'L','GAA':'E','GAC':'E','GAG':'P','GCU':'P','GGA':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P',
   'CCC':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P','CCC':'P',
   }
Seq="QHQFSP"
jj=permutate_all_substrings(Seq)
print(jj)
List=[]
for k in jj:
    # print(getAminoWeight(k))
    if getAminoWeight(k) == ParentMass:
           List.append(k)
# Out:
# [('Q', 'H', 'Q', 'F', 'S'), ('Q', 'H', 'Q', 'F', 'P'), ('Q', 'H', 'Q', 'S', 'F'), ('Q', 'H', 'Q', 'S', 'P'), ('Q', 'H', 'Q', 'P', 'F'), ('Q', 'H', 'Q', 'P', 'S'), ('Q', 'H', 'F', 'Q', 'S'), ('Q', 'H', 'F', 'Q', 'P'), ('Q', 'H', 'F', 'S', 'Q'), ('Q', 'H', 'F', 'S', 'P'), ('Q', 'H', 'F', 'P', 'Q'), ('Q', 'H', 'F', 'P', 'S'), ('Q', 'H', 'S', 'Q', 'F'), ('Q', 'H', 'S', 'Q', 'P'), ('Q', 'H', 'S', 'F', 'Q'), ('Q', 'H', 'S', 'F', 'P'), ('Q', 'H', 'S', 'P', 'Q'), ('Q', 'H', 'S', 'P', 'F'), ('Q', 'H', 'P', 'Q', 'F'), ('Q', 'H', 'P', 'Q', 'S'), ('Q', 'H', 'P', 'F', 'Q'), ('Q', 'H', 'P', 'F', 'S'), ('Q', 'H', 'P', 'S', 'Q'), ('Q', 'H', 'P', 'S', 'F'), ('Q', 'Q', 'H', 'F', 'S'), ('Q', 'Q', 'H', 'F', 'P'), ('Q', 'Q', 'H', 'S', 'F'), ('Q', 'Q', 'H', 'S', 'P'), ('Q', 'Q', 'H', 'P', 'F'), ('Q', 'Q', 'H', 'P', 'S'), ('Q', 'Q', 'F', 'H', 'S'), ('Q', 'Q', 'F', 'H', 'P'), ('Q', 'Q', 'F', 'S', 'H'), ('Q', 'Q', 'F', 'S', 'P'), ('Q', 'Q', 'F', 'P', 'H'), ('Q', 'Q', 'F', 'P', 'S'), ('Q', 'Q', 'S', 'H', 'F')
# ...

# %%
print(List)
# Out:
# []
